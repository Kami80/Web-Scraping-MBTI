# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.16personalities.com/country-profiles/iran"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="" name="description"/>
# <meta content="" name="keywords"/>
# <meta content="" name="author"/>
# <meta content="MTKwnNoP1YK21rEZd3FBJBUFkh6cvPmc9HcR9a8e" name="csrf-token"/>
# <meta content="v2.7.23" name="app-version"/>
# <meta content="country-profiles.country" name="app-route"/>
# <meta content="0" name="app-bs-uid"/>
# <meta content="" name="api-token"/>
# <meta content="en" name="app-locale"/>
# <meta content="326516237427150" property="fb:app_id"/>
# <meta content="16Personalities" property="og:site_name"/>
# <meta content="Iran Personality Profile | Country Personality Profiles | 16Personalities" property="og:title"/>
# ...

# %%
#pupolation and respondent
title = soup.find("title")
country_elements = soup.find("div", class_="country-individual")
pupolation = "".join(country_elements.find("div", class_="info-panel").find_all("div", class_="demographics")[0].find_all("span")[1].text.split(","))
respondent = "".join(country_elements.find("div", class_="info-panel").find_all("div", class_="demographics")[1].find_all("span")[1].text.split(","))

# %%
#top personality types
dictionary = {}
dic = (eval(str(country_elements.find("div", class_="panel types").find("country-profiles-top-ten-list")).split("[")[1].split("]")[0]))
dictionary["Iran"] = {
        "pupolation": pupolation,
        "respondent": respondent,
        "top_personaliy": dic
    }
dictionary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #top personality types
#       2 dictionary = {}
# ----> 3 dic = (eval(str(country_elements.find("div", class_="panel types").find("country-profiles-top-ten-list")).split("[")[1].split("]")[0]))
#       4 dictionary["Iran"] = {
#       5         "pupolation": pupolation,
#       6         "respondent": respondent,
#       7         "top_personaliy": dic
#       8     }
#       9 dictionary
#
# NameError: name 'country_elements' is not defined

# %%
from Countries import all_countries
for country in all_countries:
    country = '-'.join(country[1].split(',')[0].split())

# %%
int("".join("81,234,124".split(",")))
# Out:
# 81234124

# %%
country_elements.find("div", class_="panel types")
# Out:
# <div class="panel types">
# <h3 class="title">Top personality types</h3>
# ...
